# %%
# !pip install -U pip setuptools wheel
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: pip in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (61.2.0)
# Collecting setuptools
#   Downloading setuptools-67.6.1-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: wheel in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (0.37.1)
# Collecting wheel
#   Downloading wheel-0.40.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 2.8 MB/s eta 0:00:011
# WARNING: Error parsing requirements for astunparse: [Errno 2] No such file or directory: '/Users/florian/opt/anaconda3/lib/python3.9/site-packages/astunparse-1.6.3.dist-info/METADATA'
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.37.1
#     Uninstalling wheel-0.37.1:
#       Successfully uninstalled wheel-0.37.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 61.2.0
#     Uninstalling setuptools-61.2.0:
#       Successfully uninstalled setuptools-61.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires astunparse>=1.6.0, which is not installed.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.1 which is incompatible.
# Successfully installed pip-23.0.1 setuptools-67.6.1 wheel-0.40.0
# Requirement already satisfied: spacy in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Collecting spacy
#   Downloading spacy-3.5.2-cp39-cp39-macosx_10_9_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.27.1)
# Requirement already satisfied: pathy>=0.10.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: jinja2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: packaging>=20.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: numpy>=1.15.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.21.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: setuptools in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (67.6.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (5.2.1)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.9-cp39-cp39-macosx_10_9_x86_64.whl (865 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 kB 5.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.1.2)
# WARNING: Error parsing requirements for astunparse: [Errno 2] No such file or directory: '/Users/florian/opt/anaconda3/lib/python3.9/site-packages/astunparse-1.6.3.dist-info/METADATA'
# Installing collected packages: spacy-legacy, thinc, spacy
#   Attempting uninstall: spacy-legacy
#     Found existing installation: spacy-legacy 3.0.10
#     Uninstalling spacy-legacy-3.0.10:
#       Successfully uninstalled spacy-legacy-3.0.10
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.3
#     Uninstalling spacy-3.4.3:
#       Successfully uninstalled spacy-3.4.3
# Successfully installed spacy-3.5.2 spacy-legacy-3.0.12 thinc-8.1.9
# 2023-04-12 13:35:57.414338: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 5.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.21.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: jinja2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pathy>=0.10.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.0)
# Requirement already satisfied: setuptools in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.6.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: packaging>=20.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/florian/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# WARNING: Error parsing requirements for astunparse: [Errno 2] No such file or directory: '/Users/florian/opt/anaconda3/lib/python3.9/site-packages/astunparse-1.6.3.dist-info/METADATA'
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
# Out:
# 2023-04-12 13:36:52.611566: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nlp = spacy.load("en_core_web_sm")
